# %%
#prefills

# %%
import numpy as np
arr1=np.zeros((3,3))
print(arr1)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]

# %%
arr2=np.ones((2,3))
print(arr2)
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]]

# %%
arr3=np.full((3,4),100)
print(arr3.shape,arr3)
# Out:
# (3, 4) [[100 100 100 100]
#  [100 100 100 100]
#  [100 100 100 100]]

# %%
#some prop
'''arr.shape,size,dtype,ndim,astype'''
