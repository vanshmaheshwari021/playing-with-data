# %% [markdown]
# reshaping array

# %%
import numpy as np
arr=np.array([[1,4,3],[1,2,3]])
arr2=arr.reshape((3,2))
print(arr)
print(arr2.shape,arr2)
# Out:
# [[1 4 3]
#  [1 2 3]]
# (3, 2) [[1 4]
#  [3 1]
#  [2 3]]

# %%
#to make 2d to 1 d we can use flattern
