# %%
#indexing
import numpy as np
arr=np.array([[1,4,3],[1,2,3]])
print(arr[0,2])
# Out:
# 3

# %%
#fancy indexing
arr2=np.array([1,4,3,1,2,3])
idx=[0,2]
print(arr2[idx])
#perticular values
# Out:
# [1 3]

# %%
#booliean indexing
arr2=np.array([1,4,3,1,2,3])
print(arr2[arr2>3])
# Out:
# [4]
