# %%
import json
'''load data'''
# Out:
# 'load data'

# %%
def load(filename):
    with open(filename,"r") as f:
        data=json.load(f)
        return data

# %%
data=load("data.json")

# %%
'''cleaning and structring'''
# Out:
# 'cleaning and structring'

# %%
clean(data)
# Out:
# {'name': 'Rahul Sharma', 'feedback': 'Excellent service and quick delivery.', 'rating': 5, 'age': 24}
# {'name': 'Priya Verma', 'feedback': 'Product quality was good.', 'rating': '4', 'age': 29}
# {'name': 'Amit Singh', 'feedback': 'Average experience, can be improved.', 'rating': 3.5, 'age': None}
# {'name': 'Sneha Patel', 'feedback': 'Customer support was very helpful.', 'rating': 'Five', 'age': 27}
# {'name': 'Rohit Mehta', 'feedback': 'Delivery was delayed.', 'rating': 2, 'age': ''}
# {'name': 'Anjali Gupta', 'feedback': 'Satisfied with the purchase.', 'rating': True, 'age': 22}
# {'name': 'Rahul Sharma', 'feedback': 'Excellent service and quick delivery.', 'rating': 5, 'age': 24}
# {'name': 'Priya Verma', 'feedback': 'Product quality was good.', 'rating': '4', 'age': 29}

# %%
    def clean(data):
        tn={"one":1,"two":2,"three":3,"four":4,"five":5}
        for user in data:
            rrating=user["rating"].strip().lower()
            if rrating in tn:
                rrating=tn[rrating]
                user["rating"]=rrating
                print(rrating)

# %%
clean(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 clean(data)
#
# Cell In[37], line 4, in clean(data)
#       2 tn={"one":1,"two":2,"three":3,"four":4,"five":5}
#       3 for user in data:
# ----> 4     rrating=user["rating"].strip().lower()
#       5     if rrating in tn:
#       6         rrating=tn[rrating]
#
# AttributeError: 'int' object has no attribute 'strip'
